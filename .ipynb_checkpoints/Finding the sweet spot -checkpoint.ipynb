# %%
import pandas as pd
import numpy as np
from IPython.display import Image
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Image(filename = "img/Next step flow.jpg")

# %%
df = pd.read_excel("wine_review_2.xlsx")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Unnamed: 0.1                 0
# country                      0
# description                  0
# designation              12044
# points                       0
# price                        0
# province                     0
# region_1                     0
# region_2                 38459
# taster_name               6550
# taster_twitter_handle     6550
# title                        0
# variety                      0
# winery                       0
# years                        0
# dtype: int64

# %% [markdown]
# ## Step 1: Choose one latest year with sufficient region and grape variety counts

# %%
def choose_year(country):
    country = str(country)
    data = df[df['country'] == str(country)]
    data = data.groupby(['years'])['price'].agg(['count','min','max', 'mean']).reset_index()#.set_index('region_1')
    return data

# %%
# choosing the year
country_list = ['France','Italy','Spain']
for country in country_list:
    print(country,'\n')
    display(choose_year(country).sort_values('count', ascending = False).head(1))
# Out:
# France
#     years  count  min   max      mean
# 29   2014   3118    7  2500  40.03143
# Italy
#     years  count  min  max       mean
# 31   2012   2175    6  400  39.368736
# Spain
#     years  count  min  max       mean
# 29   2011    707    7  351  30.618105

# %% [markdown]
# ## Step 2:  Group by region and grape type
# ## Step 3: Sort per region and take highest x% of prices
#
#  1. Filter the low count regions
#  2. sort price per region
#  3. get the top 50% of the highest price ('we will consider this as sweet spot')

# %%
def filter_year(df, country, year, percent, limit):
    final_df = df
    country = str(country)
    data = final_df[(final_df['country'] == str(country)) & (final_df['years'] == year)]
    data = data.groupby(['region_1','variety','years'])['price'].agg(['count','min','max', 'mean','median']).reset_index()
    data_filtered = data[data['count'] > limit]
    result = (data_filtered.groupby('region_1',group_keys=False).apply(lambda x: x.nlargest(round(len(x) * percent), 'median')))
    return result

# %% [markdown]
# ### Step 2 and Step 3 applied to France

# %%
country = 'France'
year = 2014
a = 0.50001
#a = 1.00001
france_regions = filter_year(df,country,year,a,5)

# %%
france_regions
# Out:
#           region_1             variety  years  count  min  max        mean  \
# 6           Alsace              Muscat   2014      7   23   65   34.714286
# 12          Alsace            Riesling   2014    157   13  120   34.643312
# 5           Alsace      Gewürztraminer   2014     49   14   55   29.061224
# 9           Alsace          Pinot Gris   2014     77   15   83   29.740260
# 10          Alsace          Pinot Noir   2014     18   18   55   25.722222
# ..             ...                 ...    ...    ...  ...  ...         ...
# 377  Vin de France  Cabernet Sauvignon   2014      6   10   17   13.500000
# 401    Viré-Clessé          Chardonnay   2014     12   22   40   28.166667
# 402         Volnay          Pinot Noir   2014      8   63  145   99.500000
# 403  Vosne-Romanée          Pinot Noir   2014      7   70  220  143.571429
# 404        Vouvray        Chenin Blanc   2014     20   10   40   21.750000
#
#      median
# 6      30.0
# 12     30.0
# 5      27.0
# 9      25.0
# ...

# %% [markdown]
# ### Step 2 and Step 3 applied to Spain

# %%
country = 'Spain'
year = 2011
a = 0.50001
spain_regions = filter_year(df,country,year,a,5)
len(spain_regions['region_1'].unique())
# Out:
# 16

# %% [markdown]
# ### Step 2 and Step 3 applied to Italy

# %%
country = 'Italy'
year = 2012
a = 0.50001
italy_regions = filter_year(df,country,year,a,5)
italy_regions # get the median instead
# Out:
#                                               region_1            variety  \
# 1                                Aglianico del Vulture          Aglianico
# 13                                          Alto Adige         Pinot Nero
# 6                                           Alto Adige     Gewürztraminer
# 8                                           Alto Adige            Lagrein
# 26                          Amarone della Valpolicella          Red Blend
# 27                 Amarone della Valpolicella Classico          Red Blend
# 28                                          Barbaresco           Nebbiolo
# 29                                      Barbera d'Alba            Barbera
# 30                            Barbera d'Alba Superiore            Barbera
# 31                                      Barbera d'Asti            Barbera
# 32                            Barbera d'Asti Superiore            Barbera
# 34                                              Barolo           Nebbiolo
# ...

# %% [markdown]
# # Step 4: See what the temperatures were for those x% top grape variety

# %%
# check the temperature data and what's the annual temperature of these regions. 


class Sweetspot_temp:
    
    def get_sweet_spot(self, country_regions, cleaned_df_path, addition_data, year):
        path = cleaned_df_path
        data = pd.read_excel(addition_data)
        # get the list of the regions in each country
        regions = country_regions['region_1'].unique()
        print(f'There are {len(regions)} regions.')
        
        all_files = []
        for subdir, dirs, files in os.walk(path):
            for file in files: 
                all_files.append(file.split('.')[0])
                
        print('Number of file in directory: ',len(all_files))
        # for each region find it in local drive
        region_not_found = []
        annual_temp_df = pd.DataFrame({'region_found':[],'region_1':[],'ann_temperature':[], 'ann_humidity':[]})
        for region in regions:
            paths = path +'\\'+ str(region)+'.csv'
            # check if the region temperature is downloaded
            try: 
                if region in all_files:
                    region_df = pd.read_csv(paths, sep=',')
                    avg_annual_temp = region_df[(region_df['YEAR'] == year) & (region_df['PARAMETER'] == 'T2M')]['ANN'].values
                    avg_humidity = region_df[(region_df['YEAR'] == year) & (region_df['PARAMETER'] == 'RH2M')]['ANN'].values
                    annual_temp_df = annual_temp_df.append({'region_1':region,
                                                            'region_found':region,
                                                           'ann_temperature':avg_annual_temp,
                                                           'ann_humidity':avg_humidity},
                                                          ignore_index = True)

                else:
                    for index, row in data.iterrows():
                        if (row['region_hit'] == str(region)) or (row['region_no_hit'] == str(region)):
                            region_found = row['Region Found']
                            ## put here the original region too and append the original region to the dataframe
                            path2 = path +'\\'+ str(region_found)+'.csv'
                            region_df = pd.read_csv(path2, sep=',')
                            avg_annual_temp = region_df[(region_df['YEAR'] == year) & (region_df['PARAMETER'] == 'T2M')]['ANN'].values
                            avg_humidity = region_df[(region_df['YEAR'] == year) & (region_df['PARAMETER'] == 'RH2M')]['ANN'].values
                            annual_temp_df = annual_temp_df.append({'region_1':region,
                                                                    'region_found':region_found,
                                                                   'ann_temperature':avg_annual_temp,
                                                                   'ann_humidity':avg_humidity},
                                                                  ignore_index = True)
                            
                            
            except:
                continue
                print(region)
        
        return annual_temp_df

# %%
data_path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\climate-change-earth-surface-temperature-data\new\region_not_found_france_df_2.xlsx"
path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\france_cleaned"
fr = Sweetspot_temp()
year = 2014
france_sweetspot = fr.get_sweet_spot(france_regions, path,data_path,year)
# Out:
# There are 96 regions.
# Number of file in directory:  271

# %%
france_sweetspot
# Out:
#         region_found          region_1 ann_temperature ann_humidity
# 0             Alsace            Alsace         [10.45]      [81.68]
# 1              Anjou             Anjou         [10.99]      [79.24]
# 2             Bandol            Bandol         [15.56]      [74.19]
# 3         Beaujolais        Beaujolais         [20.04]      [77.74]
# 4   Beaujolais Blanc  Beaujolais Blanc          [11.5]      [80.59]
# ..               ...               ...             ...          ...
# 90     Vin de France     Vin de France         [10.59]      [76.78]
# 91       Viré-Clessé       Viré-Clessé          [11.5]      [80.59]
# 92            Volnay            Volnay         [10.67]      [84.29]
# 93     Vosne-Romanée     Vosne-Romanée         [10.67]      [84.29]
# 94           Vouvray           Vouvray          [12.3]      [81.55]
#
# [95 rows x 4 columns]

# %%
data_path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\climate-change-earth-surface-temperature-data\new\italy_regions_to_confirm.xlsx"
path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned"
it = Sweetspot_temp()
year = 2012
italy_sweetspot = it.get_sweet_spot(italy_regions, path,data_path,year)
# Out:
# There are 51 regions.
# Number of file in directory:  194

# %%
data_path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\climate-change-earth-surface-temperature-data\new\spain_region_to_confirm.xlsx"
path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned"
sp= Sweetspot_temp()
year = 2011
spain_sweetspot = sp.get_sweet_spot(spain_regions, path,data_path,year)
# Out:
# There are 16 regions.
# Number of file in directory:  62

# %%
spain_sweetspot
# Out:
#         region_found          region_1 ann_temperature ann_humidity
# 0             Bierzo            Bierzo         [10.79]      [72.54]
# 1          Calatayud         Calatayud         [12.41]      [62.05]
# 2               Cava              Cava         [10.05]      [66.49]
# 3            Jumilla           Jumilla         [16.74]      [60.21]
# 4          La Mancha         La Mancha         [11.96]       [84.0]
# 5           Montsant          Montsant         [16.15]      [70.08]
# 6            Navarra           Navarra         [12.46]      [76.05]
# 7            Priorat           Priorat         [15.92]      [66.62]
# 8   Ribera del Duero  Ribera del Duero         [11.55]      [67.19]
# 9              Rioja             Rioja         [11.82]      [69.46]
# 10             Rueda             Rueda          [8.73]      [78.68]
# 11       Rías Baixas       Rías Baixas         [22.17]       [76.8]
# 12              Toro              Toro         [12.64]      [65.52]
# ...

# %% [markdown]
# # Step 5: Put back sweetspots to the regions and compare the distribution

# %%
france_regions
france = france_regions.merge(france_sweetspot, how = 'inner')
france['ann_temperature'] = france['ann_temperature'].str[0]
france['ann_humidity'] = france['ann_humidity'].str[0]

italy_regions 
italy = italy_regions.merge(italy_sweetspot, how = 'inner')
italy['ann_temperature'] = italy['ann_temperature'].str[0]
italy['ann_humidity'] = italy['ann_humidity'].str[0]

spain_regions
spain = spain_regions.merge(spain_sweetspot, how = 'inner')
spain['ann_temperature'] = spain['ann_temperature'].str[0]
spain['ann_humidity'] = spain['ann_humidity'].str[0]

# %%
# snippet how dataframe looks like
spain # add in another column the predicted temperature in 20 years
# Out:
#             region_1            variety  years  count  min  max       mean  \
# 0             Bierzo             Mencía   2011     19    8  100  36.157895
# 1          Calatayud           Garnacha   2011     10    8   30  16.300000
# 2               Cava    Sparkling Blend   2011     30   13   59  27.800000
# 3            Jumilla         Monastrell   2011     10    9   30  18.400000
# 4          La Mancha        Tempranillo   2011     10    7   28  15.300000
# 5           Montsant          Red Blend   2011     12   10   45  23.666667
# 6            Navarra          Red Blend   2011      6   12   25  18.833333
# 7            Navarra           Garnacha   2011      6    7   13  10.666667
# 8            Priorat          Red Blend   2011     17   15   95  28.588235
# 9   Ribera del Duero         Tinto Fino   2011     15   12  150  58.466667
# 10  Ribera del Duero        Tempranillo   2011     75    9  351  56.560000
# ...

# %%
# check distribution
# France for year 2014
fig = plt.figure(figsize=(10,6))
lst1 = france['ann_temperature']
lst2 = france['ann_humidity']
sns.distplot(lst1)
sns.distplot(lst2)
fig.legend(labels=['annual temperature','annual humidity'])
plt.show()

# %%
# Italy for year 2012

fig = plt.figure(figsize=(10,6))
lst1 = italy['ann_temperature']
lst2 = italy['ann_humidity']
sns.distplot(lst1)
sns.distplot(lst2)
fig.legend(labels=['annual temperature','annual humidity'])
plt.show()

# %%
# year 2011
fig = plt.figure(figsize=(10,6))
lst1 = spain['ann_temperature']
lst2 = spain['ann_humidity']
sns.distplot(lst1)
sns.distplot(lst2)
fig.legend(labels=['annual temperature','annual humidity'])
plt.show()

# %%
path = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned"

df = pd.read_csv(path+'\\'+'Abruzzo.csv')

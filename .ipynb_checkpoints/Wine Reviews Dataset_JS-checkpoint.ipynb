# %% [markdown]
# Dataset Overview:
#
# The wine reviews dataset has been retrieved from Kaggle.com. The dataset has been posted by Zack Thoutt. The data has been scraped from WineEnthusiast on Nov. 22, 2017.

# %% [markdown]
# ## The purpose of the Exploratory data analysis are the following:
#
# 1. Find patterns on each region based on price of the wine and year.
# 2. Find patterns on each region based on the points of the wine and year.
# 3. Find patterns on each region based on the price of the wine and year per variety.
# 4. Find patterns on each region based on the points of the wine and year per variety.
# 5. Know the distribution of regions in each country.
# 6. Know the distributions of regions that have price filled up.
# 7. Know the distributions of regions that have points filled up.
#
# ======================================================================================= <br>
# Analyis performed:
#
# 1. Apply regression on each country based on price of the wine and year per region.
# 2. Apply regression on each country based on points of the wine and year per region.
# 3. Apply regression on each country based on price of different varieties and year per region.
# 4. Apply regression on each country based on points of different varieties and year per region.

# %%
# for plotting
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

#for the image
from IPython.display import Image

# pandas
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from glob import glob
import numpy as np
import os,re,string
import warnings
warnings.filterwarnings("ignore")
import time

import nltk
from spacy.tokens import Doc
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
from nltk import word_tokenize          
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
nltk.download('wordnet')

#models
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
import re

# statistics 
from statsmodels.formula.api import ols

#metrics 
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn import metrics

# visualization 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
from matplotlib import pyplot

# nlp
import spacy
#nlp_spacy = spacy.load('en')
import operator

import en_core_web_sm
nlp = spacy.load('en_core_web_sm')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words_nltk = set(stopwords.words('english'))
# update stopword
#stop_words_list = stop_words_nltk.union(customize_stop_words)

from nltk.stem import PorterStemmer 
from nltk.stem.snowball import SnowballStemmer

ps = PorterStemmer() 
sb = SnowballStemmer('english')
import time
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rezan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
stop_words_nltk.update({"isnt"})

# %% [markdown]
# # EDA: Wine Reviews

# %%
def get_reviews_df():
    reviews = pd.read_csv('winemag-data-130k-v2.csv')
    print(f'Initial DataFrame: {reviews.info()}')
    # check the null values
    print('Percentage of null values in the dataframe')
    reviews.isnull().sum()/len(reviews)
    # list of EU countries
    eu_countries = ['Albania', 'Andorra' , 'Armenia', 'Austria', 'Azerbaijan', 'Belarus', 'Belgium', 
                    'Bosnia', 'Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Estonia',
                    'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 
                    'Italy', 'Kazakhstan', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 
                    'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia (formerly Macedonia)', 
                    'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain',
                    'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom (UK)', 'Vatican City (Holy See)']

    # get only the wines with title in reviews that has year and only the countries within europe. 
    # this will be the wine to be used from now on.
    reviews['years'] = reviews.title.str.extract('([1-2][0-9]{3})').astype('float64')
    reviews = reviews[reviews['years'] < 2020] 
    filtered_wine_reviews = reviews['country'].isin(eu_countries)
    reviews_df = reviews[filtered_wine_reviews]
    print(f'shape of dataframe after filtering the countries and the years from the wine title.: {reviews_df.shape}')
    print(f'checking the null values after filtering {reviews_df.isnull().sum()/len(reviews_df)}')
    return reviews_df

reviews_df = get_reviews_df()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
# Unnamed: 0               129971 non-null int64
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB
# Initial DataFrame: None
# Percentage of null values in the dataframe
# shape of dataframe after filtering the countries and the years from the wine title.: (57307, 15)
# checking the null values after filtering Unnamed: 0               0.000000
# country                  0.000000
# description              0.000000
# designation              0.279477
# points                   0.000000
# price                    0.139267
# province                 0.000000
# region_1                 0.213011
# region_2                 1.000000
# taster_name              0.142443
# taster_twitter_handle    0.176122
# title                    0.000000
# variety                  0.000000
# winery                   0.000000
# years                    0.000000
# dtype: float64

# %% [markdown]
# notes from the dataset: <br>
# region_1: The wine growing area in a province or state (ie Napa) <br>
# region_2: Sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this value can sometimes be blank

# %% [markdown]
# Remarks: Region_2 will not be included since it is completely unfilled.

# %% [markdown]
# # Descriptive analysis about countries and regions
#
# - Region is a very important factor since this is where the prediction will be based.

# %%
def eda_per_country_counts(reviews_df):
    sns.catplot('country', data=reviews_df, kind='count', height=13, aspect=3, orient='v')
    print(
        'how many countries are captured after filtering\n', 
        reviews_df['country'].value_counts()
    )
    
eda_per_country_counts(reviews_df)
# Out:
# how many countries are captured after filtering
#  France         20511
# Italy          18550
# Spain           6142
# Portugal        5374
# Austria         3304
# Germany         2149
# Greece           445
# Hungary          143
# Bulgaria         141
# Romania          120
# Turkey            90
# Slovenia          85
# Georgia           84
# Croatia           72
# Moldova           57
# Serbia            12
# Cyprus            10
# Switzerland        7
# Ukraine            5
# Luxembourg         3
# Armenia            2
# Slovakia           1
# Name: country, dtype: int64

# %% [markdown]
# remarks: Count of countries that was filtered.

# %%
def eda_countries_available_regions(reviews_df):
    data_countries_region_1 = reviews_df.groupby('country')['region_1'].agg(['count']).reset_index().sort_values('count', ascending = False)
    print("how many countries that has available 'regions'. \n", data_countries_region_1[data_countries_region_1['count'] != 0])
    sns.barplot('country','count', data = data_countries_region_1[data_countries_region_1['count'] != 0])

eda_countries_available_regions(reviews_df)
# Out:
# how many countries that has available 'regions'.
#     country  count
# 5   France  20435
# 10   Italy  18531
# 18   Spain   6134

# %% [markdown]
# Remarks: These are the countries that have regions available. The analysis will be focus on these 3 countries.

# %%
def eda_checking_null_values(reviews_df):
    # checking how many null values are available after filtering from 3 different countries. (France, Italy, Spain)
    list_of_countries_contains_R1 = ['France','Italy','Spain']
    print('Check if the null values in region_1 : \n',
        reviews_df[reviews_df['country'].isin(list_of_countries_contains_R1)].isnull().sum()
    )
    
    # check from the where those null region_1 are: 

    data = reviews_df[reviews_df['country'].isin(list_of_countries_contains_R1)]
    data_toCheck = data[data['region_1'].isnull()] # check which country got a lot of null regions 
    print('Count of null values in each countries:\n', data_toCheck['country'].value_counts())
    print('\n')
    print(
        'Percentage of null regions in France out of 20511:', 
        (
            len(data_toCheck[data_toCheck['country'] == 'France']
        )/len(reviews_df[reviews_df['country'] == 'France']))*100
    )
    print(
        'Percentage of null regions in Italy out of 18550:',
        (
            len(data_toCheck[data_toCheck['country'] == 'Italy']
        )/len(reviews_df[reviews_df['country'] == 'Italy']))*100
    )
    print(
        'Percentage of null regions in Spain out of 6142:',
        (
            len(data_toCheck[data_toCheck['country'] == 'Spain']
        )/len(reviews_df[reviews_df['country'] == 'Spain']))*100
    )
eda_checking_null_values(reviews_df)
# Out:
# Check if the null values in region_1 :
#  Unnamed: 0                   0
# country                      0
# description                  0
# designation              14412
# points                       0
# price                     6650
# province                     0
# region_1                   103
# region_2                 45203
# taster_name               8120
# taster_twitter_handle     8120
# title                        0
# variety                      0
# winery                       0
# years                        0
# dtype: int64
# Count of null values in each countries:
#  France    76
# Italy     19
# Spain      8
# Name: country, dtype: int64
#
#
# Percentage of null regions in France out of 20511: 0.3705328847935254
# Percentage of null regions in Italy out of 18550: 0.10242587601078167
# Percentage of null regions in Spain out of 6142: 0.1302507326603712

# %% [markdown]
# There are 103 unfilled regions. 6650 unfilled price.

# %% [markdown]
# **Note:** Based on the observation above,  since region is a very important variable in this study,  we will discard all the other countries that have unfilled region.

# %%
def eda_get_final_data(reviews_df):
    # get only the 3 countries and remove the 103 null regions. 

    countries_to_include = ['France','Italy', 'Spain']
    final_data = reviews_df[reviews_df['country'].isin(countries_to_include)]
    final_data = reviews_df[~reviews_df['region_1'].isnull()] # drop the null regions from filtered data
    print('Shape of the final data: ', final_data.shape)
    print(final_data.isnull().sum())
    
    return final_data
    
final_data = eda_get_final_data(reviews_df)
# Out:
# Shape of the final data:  (45100, 15)
# Unnamed: 0                   0
# country                      0
# description                  0
# designation              14396
# points                       0
# price                     6641
# province                     0
# region_1                     0
# region_2                 45100
# taster_name               8120
# taster_twitter_handle     8120
# title                        0
# variety                      0
# winery                       0
# years                        0
# dtype: int64

# %% [markdown]
# **Note:** After getting the countries that have region_1 filled and within SPAIN, FRANCE, and ITALY. We are left with 45100x15 shape.

# %%
def eda_descriptive_analysis_years_per_country(final_data):
    # descriptive analysis of years recorded per country

    final_data.groupby('country')['years'].agg(['count','min','max', 'mean'])

eda_descriptive_analysis_years_per_country(final_data)

# %%
# small view on the final data 

final_data.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
# 5           5   Spain  Blackberry and raspberry aromas show a typical...
# 6           6   Italy  Here's a bright, informal red that opens with ...
# 7           7  France  This dry and restrained wine offers spice in p...
# 9           9  France  This has great depth of flavor with its fresh ...
#
#     designation  points  price           province  region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 5  Ars In Vitro      87   15.0     Northern Spain   Navarra      NaN
# 6       Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# 7           NaN      87   24.0             Alsace    Alsace      NaN
# 9   Les Natures      87   27.0             Alsace    Alsace      NaN
#
#          taster_name taster_twitter_handle  \
# 0      Kerin O’Keefe          @kerinokeefe
# 5  Michael Schachner           @wineschach
# 6      Kerin O’Keefe          @kerinokeefe
# 7         Roger Voss            @vossroger
# 9         Roger Voss            @vossroger
#
#                                                title             variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 5  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 7              Trimbach 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 9  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...          Pinot Gris
#
#                winery   years
# 0             Nicosia  2013.0
# 5              Tandem  2011.0
# 6     Terre di Giurfo  2013.0
# 7            Trimbach  2012.0
# 9  Jean-Baptiste Adam  2012.0

# %%
final_data.to_excel('wine_review_1.xlsx')

# %%
final_data.shape
# Out:
# (45100, 15)

# %% [markdown]
# # France distribution of Regions

# %%
# distribution of region recorded in France

france = final_data[final_data['country'] == 'France']
count_france = pd.DataFrame(france.groupby('region_1')['region_1'].count())
count_france['region_1'].describe()
# Out:
# count     382.000000
# mean       53.494764
# std       146.937142
# min         1.000000
# 25%         3.000000
# 50%        11.000000
# 75%        37.750000
# max      2125.000000
# Name: region_1, dtype: float64

# %%
boxplot_france = count_france.boxplot(column = 'region_1', figsize = (10,10))

# %% [markdown]
# # Italy distribution of regions

# %%
italy = final_data[final_data['country'] == 'Italy']
count_italy = pd.DataFrame(italy.groupby('region_1')['region_1'].count())
count_italy['region_1'].describe()
# Out:
# count     379.000000
# mean       48.894459
# std       160.409313
# min         1.000000
# 25%         3.000000
# 50%         8.000000
# 75%        26.000000
# max      1599.000000
# Name: region_1, dtype: float64

# %%
boxplot_italy = count_italy.boxplot(column = 'region_1', figsize = (10,10))

# %% [markdown]
# # Spain distributions of regions

# %%
spain = final_data[final_data['country'] == 'Spain']
count_spain = pd.DataFrame(spain.groupby('region_1')['region_1'].count())
count_spain['region_1'].describe()
# Out:
# count      80.00000
# mean       76.67500
# std       190.10988
# min         1.00000
# 25%         4.00000
# 50%        11.50000
# 75%        71.50000
# max      1466.00000
# Name: region_1, dtype: float64

# %%
boxplot_spain = count_spain.boxplot(column = 'region_1', figsize = (10,10))

# %% [markdown]
# ## Comparing the distribution of regions in FRANCE, ITALY, and SPAIN

# %%
# combine all 3 dataframe and check how skewed the data are. 

count_france.rename({'region_1':'France Region'},axis=1, inplace=True)
count_italy.rename({'region_1':'Italy Region'},axis=1, inplace=True)
count_spain.rename({'region_1':'Spain Region'},axis=1, inplace=True)

all_countries = pd.concat([count_france,count_italy,count_spain], axis = 1)
all_countries.boxplot(column = ['France Region', 'Italy Region', 'Spain Region' ], figsize = (10,10))

# %% [markdown]
# Remarks: In all countries, the distribution of the recorded regions has been really skewed. For France, the minimum is 1 and the maximum is 2125. For Italy, the minimum is 1 and maximum is 1599. For Spain, the minimum is 1 and maximum is 1466. Please refer to the results above for more details and remarks.

# %% [markdown]
# # Analysis about regions and price
#
# - The price variable is important to have since this is an indication of the quality of the wine on that year per region. <br>

# %%
final_data.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                      0
# description                  0
# designation              14396
# points                       0
# price                     6641
# province                     0
# region_1                     0
# region_2                 45100
# taster_name               8120
# taster_twitter_handle     8120
# title                        0
# variety                      0
# winery                       0
# years                        0
# dtype: int64

# %% [markdown]
# * We have 6641 null values for price.

# %%
# check which country contains a lot of null values for price. 

final_data_toCheck = final_data[final_data['price'].isnull()]
print('Count of null values in each countries:\n', final_data_toCheck['country'].value_counts())
# Out:
# Count of null values in each countries:
#  France    4116
# Italy     2457
# Spain       68
# Name: country, dtype: int64

# %% [markdown]
# Remarks: These are the count of the null values for price variable in each country.

# %%
# count of regions that has no available price

final_data_toCheck = final_data[final_data['price'].isnull()]
print('Count of null values in each region:\n', final_data_toCheck['region_1'].value_counts())
# Out:
# Count of null values in each region:
#  Saint-Émilion                        274
# Alsace                               262
# Brunello di Montalcino               259
# Barolo                               239
# Pessac-Léognan                       234
#                                     ...
# Trebbiano d'Abruzzo                    1
# Apremont                               1
# Cilento                                1
# Valpolicella Valpantena Superiore      1
# Vino de la Tierra de Castilla          1
# Name: region_1, Length: 477, dtype: int64

# %% [markdown]
# Remarks: There are 477 regions that doesnt have a price value recorded. Because of this result, the original data will be filtered and the regions that have missing values for price will be filtered. The result of this filtering will be stored in a separate dataframe called "**data_price_df**".

# %%
# get which regions has the null values 

regionWithNoPriceAvailable = list(final_data_toCheck['region_1'].unique())

df_noPrice = pd.DataFrame({'region_1':[], 'no_price_count':[], 'region_count':[], 'percentNull':[]})
for region in regionWithNoPriceAvailable:
    whole_region_count = len(final_data[final_data['region_1'] == str(region)])
    num_of_no_price =  len(final_data_toCheck[final_data_toCheck['region_1'] == str(region)])
    regPercent =num_of_no_price/whole_region_count
    df_noPrice = df_noPrice.append({'region_1':region,'percentNull':regPercent,'no_price_count':num_of_no_price, 'region_count':whole_region_count}, ignore_index = True)

# %%
df_noPrice.sort_values('percentNull', ascending = False, inplace = True)
df_noPrice.describe()
# Out:
#        no_price_count  region_count  percentNull
# count      477.000000    477.000000   477.000000
# mean        13.922432     87.993711     0.246710
# std         33.995246    202.014606     0.231452
# min          1.000000      1.000000     0.002899
# 25%          1.000000      9.000000     0.101852
# 50%          3.000000     25.000000     0.170732
# 75%         11.000000     85.000000     0.285714
# max        274.000000   2125.000000     1.000000

# %% [markdown]
# Remarks: minimum price count is 1, max region is 274.

# %%
df_noPrice.sort_values('no_price_count', ascending = False) # these are all the regions that have unfilled price.
# Out:
#                    region_1  no_price_count  region_count  percentNull
# 35            Saint-Émilion           274.0         561.0     0.488414
# 17                   Alsace           262.0        2125.0     0.123294
# 3    Brunello di Montalcino           259.0        1470.0     0.176190
# 46                   Barolo           239.0        1599.0     0.149468
# 39           Pessac-Léognan           234.0         396.0     0.590909
# ..                      ...             ...           ...          ...
# 379     Gambellara Classico             1.0           3.0     0.333333
# 92                     Faro             1.0           9.0     0.111111
# 340   Falanghina del Sannio             1.0           9.0     0.111111
# 474      Corbières-Boutenac             1.0           9.0     0.111111
# 445             Rías Baixas             1.0         345.0     0.002899
#
# [477 rows x 4 columns]

# %% [markdown]
# Remarks: The highest region that got missing value is contaning 49% of it's whole record. I will drop just drop all these null values store it in another dataframe and do regression on each region based on their price.

# %%
# get all regions that have price filled completely. 
# use this data for regression
# This data contains filled region and filled price. 
# This data will be used for regression on price and region, but this will not be used for points and region.

data_price_df = final_data[~final_data['price'].isnull()]

# %%
data_price_df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                      0
# description                  0
# designation              12044
# points                       0
# price                        0
# province                     0
# region_1                     0
# region_2                 38459
# taster_name               6550
# taster_twitter_handle     6550
# title                        0
# variety                      0
# winery                       0
# years                        0
# dtype: int64

# %% [markdown]
# Remarks: Now, after filtering we dont have a missing value for price anymore and no missing values on region_1 as well. This dataset will be used for the regression on year and price later on.

# %%
data_price_df.to_excel('wine_review_2.xlsx')

# %% [markdown]
# ## France: Region and Price distribution

# %%
# France region distribution that has price feature available. This using the price data only. 

france = data_price_df[data_price_df['country'] == 'France']
print('Shape of France DataSet: ', france.shape)
count_france_price = pd.DataFrame(france.groupby('region_1')['region_1'].count())
#count_france_price['region_1'].describe()
count_france_price['region_1'].describe()
# Out:
# Shape of France DataSet:  (16319, 15)
# count     372.000000
# mean       43.868280
# std       125.515074
# min         1.000000
# 25%         3.000000
# 50%         9.000000
# 75%        34.000000
# max      1863.000000
# Name: region_1, dtype: float64

# %% [markdown]
# Remarks: There are 372 unique regions.

# %%
boxplot_france = count_france_price.boxplot(column = 'region_1', figsize = (5,8))

# %% [markdown]
# Remarks: Lower 25 percentile is 3 and below. 75 percentile is 34 and above. I will do regression on 75% above including the outliers. Threshold of 34.

# %%
# filter price data on France 
france = data_price_df[data_price_df['country'] == 'France']

# get the region that got >= 9 and put it in a list 
count_france_price = pd.DataFrame(france.groupby('region_1')['region_1'].count())
france_regions_list = count_france_price[count_france_price['region_1'] >= 34].index.tolist()

# filter the france dataset on france_regions_list
france = france[france['region_1'].isin(france_regions_list)]

# %% [markdown]
# ### France: Regression on Years and Price Per Region.

# %%
# function on regression on years vs price per region

def regression(region, price_per_year_df):
    x = pd.DataFrame(price_per_year_df.loc[str(region)]['years']['mean'].values).rename(columns = {0:'year'})
    y = pd.DataFrame(price_per_year_df.loc[str(region)]['price']['mean'].values).rename(columns = {0:'price_mean'}) # this is the y-axis 
    price_df = pd.concat([x,y], axis = 1) # save this dataframe for future use. 
    #sns.lmplot(x='year', y='price_mean', data=price_df)
    x = sm.add_constant(x)
    model = sm.OLS(y,x) # 
    results = model.fit()
    print(results.summary())
    print('=====Result Parameters========')
    print(results.params)
    print(sns.lmplot(x='year', y='price_mean', data=price_df))
    ax = plt.gca()
    print(ax.set_title(f"{region}"))

# %%
import statsmodels.api as sm
## do lmplot and regression on each region ##

# groupby per region, get the years and the price
price_year_per_region = france.groupby(['region_1','years'])['years','price'].agg(['count','min','max', 'mean']).reset_index().set_index('region_1')
# perform regression on years and price on that region ( use the mean for years and mean for price)

france_list_region = list(price_year_per_region.index.unique())

for region in france_list_region:
    print(f'====FOR REGION {region}=====')
    regression(region,price_year_per_region)
# Out:
# ====FOR REGION Alsace=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.142
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.302
# Time:                        14:50:41   Log-Likelihood:                -60.495
# No. Observations:                  17   AIC:                             125.0
# Df Residuals:                      15   BIC:                             126.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        889.7449    801.020      1.111      0.284    -817.589    2597.079
# year          -0.4263      0.399     -1.069      0.302      -1.277       0.424
# ==============================================================================
# Omnibus:                        3.344   Durbin-Watson:                   2.437
# Prob(Omnibus):                  0.188   Jarque-Bera (JB):                1.289
# Skew:                           0.438   Prob(JB):                        0.525
# Kurtosis:                       4.026   Cond. No.                     7.33e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.33e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    889.744874
# year      -0.426340
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8810FA48>
# Text(0.5, 1.0, 'Alsace')
# ====FOR REGION Bandol=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     6.041
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0363
# Time:                        14:50:42   Log-Likelihood:                -27.637
# No. Observations:                  11   AIC:                             59.27
# Df Residuals:                       9   BIC:                             60.07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1587.7794    632.712      2.509      0.033     156.486    3019.072
# year          -0.7733      0.315     -2.458      0.036      -1.485      -0.062
# ==============================================================================
# Omnibus:                        5.202   Durbin-Watson:                   2.282
# Prob(Omnibus):                  0.074   Jarque-Bera (JB):                1.820
# Skew:                          -0.870   Prob(JB):                        0.403
# Kurtosis:                       3.972   Cond. No.                     1.28e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1587.779359
# year       -0.773283
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8700E388>
# Text(0.5, 1.0, 'Bandol')
# ====FOR REGION Beaujolais=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9977
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.347
# Time:                        14:50:42   Log-Likelihood:                -21.347
# No. Observations:                  10   AIC:                             46.69
# Df Residuals:                       8   BIC:                             47.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        519.6291    506.531      1.026      0.335    -648.434    1687.693
# year          -0.2515      0.252     -0.999      0.347      -0.832       0.329
# ==============================================================================
# Omnibus:                        9.172   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                3.864
# Skew:                           1.379   Prob(JB):                        0.145
# Kurtosis:                       4.291   Cond. No.                     1.41e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    519.629140
# year      -0.251528
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F954948>
# Text(0.5, 1.0, 'Beaujolais')
# ====FOR REGION Beaujolais-Villages=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     1.214
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.299
# Time:                        14:50:42   Log-Likelihood:                -20.462
# No. Observations:                  11   AIC:                             44.92
# Df Residuals:                       9   BIC:                             45.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -348.9248    329.539     -1.059      0.317   -1094.394     396.544
# year           0.1806      0.164      1.102      0.299      -0.190       0.551
# ==============================================================================
# Omnibus:                        2.126   Durbin-Watson:                   1.303
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.012
# Skew:                          -0.334   Prob(JB):                        0.603
# Kurtosis:                       1.673   Cond. No.                     1.28e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -348.924848
# year       0.180576
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8EF97748>
# Text(0.5, 1.0, 'Beaujolais-Villages')
# ====FOR REGION Beaune=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     4.031
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0725
# Time:                        14:50:42   Log-Likelihood:                -46.536
# No. Observations:                  12   AIC:                             97.07
# Df Residuals:                      10   BIC:                             98.04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3572.6473   1812.309     -1.971      0.077   -7610.723     465.428
# year           1.8109      0.902      2.008      0.072      -0.199       3.821
# ==============================================================================
# Omnibus:                        2.242   Durbin-Watson:                   1.462
# Prob(Omnibus):                  0.326   Jarque-Bera (JB):                0.359
# Skew:                           0.240   Prob(JB):                        0.836
# Kurtosis:                       3.698   Cond. No.                     9.85e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -3572.647322
# year        1.810931
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F127108>
# Text(0.5, 1.0, 'Beaune')
# ====FOR REGION Bergerac=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.083
# Method:                 Least Squares   F-statistic:                   0.08034
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.782
# Time:                        14:50:43   Log-Likelihood:                -40.063
# No. Observations:                  13   AIC:                             84.13
# Df Residuals:                      11   BIC:                             85.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        205.2291    670.681      0.306      0.765   -1270.929    1681.387
# year          -0.0946      0.334     -0.283      0.782      -0.829       0.640
# ==============================================================================
# Omnibus:                        8.832   Durbin-Watson:                   3.194
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                4.617
# Skew:                           1.150   Prob(JB):                       0.0994
# Kurtosis:                       4.799   Cond. No.                     8.47e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.47e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    205.229058
# year      -0.094608
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8EC0B0C8>
# Text(0.5, 1.0, 'Bergerac')
# ====FOR REGION Bergerac Sec=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     1.428
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.263
# Time:                        14:50:43   Log-Likelihood:                -53.350
# No. Observations:                  11   AIC:                             110.7
# Df Residuals:                       9   BIC:                             111.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7497.7602   6249.552      1.200      0.261   -6639.708    2.16e+04
# year          -3.7132      3.108     -1.195      0.263     -10.744       3.317
# ==============================================================================
# Omnibus:                       19.306   Durbin-Watson:                   2.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.457
# Skew:                           1.974   Prob(JB):                      0.00120
# Kurtosis:                       6.711   Cond. No.                     1.22e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    7497.760150
# year       -3.713186
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8E0B5108>
# Text(0.5, 1.0, 'Bergerac Sec')
# ====FOR REGION Blaye Côtes de Bordeaux=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     5.591
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0500
# Time:                        14:50:43   Log-Likelihood:                -18.407
# No. Observations:                   9   AIC:                             40.81
# Df Residuals:                       7   BIC:                             41.21
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1324.7380    550.936      2.405      0.047      21.981    2627.495
# year          -0.6474      0.274     -2.364      0.050      -1.295    4.43e-05
# ==============================================================================
# Omnibus:                        4.662   Durbin-Watson:                   2.328
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                1.606
# Skew:                           1.018   Prob(JB):                        0.448
# Kurtosis:                       3.368   Cond. No.                     1.57e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1324.737983
# year       -0.647449
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8B9042C8>
# Text(0.5, 1.0, 'Blaye Côtes de Bordeaux')
# ====FOR REGION Bordeaux=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     1.839
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.194
# Time:                        14:50:43   Log-Likelihood:                -80.691
# No. Observations:                  18   AIC:                             165.4
# Df Residuals:                      16   BIC:                             167.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2525.8946   1847.079      1.368      0.190   -1389.738    6441.527
# year          -1.2479      0.920     -1.356      0.194      -3.199       0.703
# ==============================================================================
# Omnibus:                       31.409   Durbin-Watson:                   2.243
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.323
# Skew:                           2.648   Prob(JB):                     7.96e-14
# Kurtosis:                      10.238   Cond. No.                     6.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    2525.894634
# year       -1.247941
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F8EA488>
# Text(0.5, 1.0, 'Bordeaux')
# ====FOR REGION Bordeaux Blanc=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     6.283
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0251
# Time:                        14:50:43   Log-Likelihood:                -42.017
# No. Observations:                  16   AIC:                             88.03
# Df Residuals:                      14   BIC:                             89.58
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -780.1012    317.509     -2.457      0.028   -1461.089     -99.113
# year           0.3964      0.158      2.507      0.025       0.057       0.736
# ==============================================================================
# Omnibus:                        1.804   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.406   Jarque-Bera (JB):                1.338
# Skew:                           0.521   Prob(JB):                        0.512
# Kurtosis:                       2.039   Cond. No.                     7.13e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -780.101152
# year       0.396397
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86C03308>
# Text(0.5, 1.0, 'Bordeaux Blanc')
# ====FOR REGION Bordeaux Rosé=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     6.120
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0426
# Time:                        14:50:44   Log-Likelihood:                -18.255
# No. Observations:                   9   AIC:                             40.51
# Df Residuals:                       7   BIC:                             40.90
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -794.8664    326.631     -2.434      0.045   -1567.225     -22.508
# year           0.4018      0.162      2.474      0.043       0.018       0.786
# ==============================================================================
# Omnibus:                       14.656   Durbin-Watson:                   2.438
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                6.435
# Skew:                           1.766   Prob(JB):                       0.0401
# Kurtosis:                       5.164   Cond. No.                     9.45e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.45e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -794.866414
# year       0.401784
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86C4F5C8>
# Text(0.5, 1.0, 'Bordeaux Rosé')
# ====FOR REGION Bordeaux Supérieur=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     4.102
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0703
# Time:                        14:50:44   Log-Likelihood:                -36.498
# No. Observations:                  12   AIC:                             77.00
# Df Residuals:                      10   BIC:                             77.96
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1908.5476    932.532      2.047      0.068    -169.263    3986.358
# year          -0.9399      0.464     -2.025      0.070      -1.974       0.094
# ==============================================================================
# Omnibus:                       12.064   Durbin-Watson:                   0.970
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                6.825
# Skew:                           1.486   Prob(JB):                       0.0330
# Kurtosis:                       5.195   Cond. No.                     1.17e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1908.547642
# year       -0.939885
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86CD22C8>
# Text(0.5, 1.0, 'Bordeaux Supérieur')
# ====FOR REGION Bourgogne=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                    0.5682
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.467
# Time:                        14:50:44   Log-Likelihood:                -49.078
# No. Observations:                  13   AIC:                             102.2
# Df Residuals:                      11   BIC:                             103.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1050.7417   1360.112      0.773      0.456   -1942.844    4044.328
# year          -0.5102      0.677     -0.754      0.467      -2.000       0.979
# ==============================================================================
# Omnibus:                       16.581   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.506
# Skew:                           1.768   Prob(JB):                      0.00192
# Kurtosis:                       6.254   Cond. No.                     8.59e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1050.741730
# year       -0.510186
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86D1AB08>
# Text(0.5, 1.0, 'Bourgogne')
# ====FOR REGION Brouilly=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.139
# Method:                 Least Squares   F-statistic:                   0.02577
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.877
# Time:                        14:50:44   Log-Likelihood:                -19.648
# No. Observations:                   9   AIC:                             43.30
# Df Residuals:                       7   BIC:                             43.69
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -68.3058    549.143     -0.124      0.905   -1366.823    1230.211
# year           0.0438      0.273      0.161      0.877      -0.602       0.689
# ==============================================================================
# Omnibus:                        0.340   Durbin-Watson:                   1.573
# Prob(Omnibus):                  0.844   Jarque-Bera (JB):                0.428
# Skew:                           0.012   Prob(JB):                        0.807
# Kurtosis:                       1.932   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -68.305801
# year      0.043817
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86D5CE48>
# Text(0.5, 1.0, 'Brouilly')
# ====FOR REGION Cadillac Côtes de Bordeaux=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     3.997
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.102
# Time:                        14:50:45   Log-Likelihood:                -20.804
# No. Observations:                   7   AIC:                             45.61
# Df Residuals:                       5   BIC:                             45.50
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4274.7548   2126.096      2.011      0.101   -1190.548    9740.058
# year          -2.1126      1.057     -1.999      0.102      -4.829       0.604
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.303
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.627
# Skew:                           0.573   Prob(JB):                        0.731
# Kurtosis:                       2.086   Cond. No.                     2.02e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    4274.754811
# year       -2.112637
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86D41F88>
# Text(0.5, 1.0, 'Cadillac Côtes de Bordeaux')
# ====FOR REGION Cahors=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.350
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.268
# Time:                        14:50:45   Log-Likelihood:                -47.910
# No. Observations:                  14   AIC:                             99.82
# Df Residuals:                      12   BIC:                             101.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1013.8268    844.323      1.201      0.253    -825.796    2853.449
# year          -0.4882      0.420     -1.162      0.268      -1.404       0.427
# ==============================================================================
# Omnibus:                        1.250   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.535   Jarque-Bera (JB):                0.887
# Skew:                           0.316   Prob(JB):                        0.642
# Kurtosis:                       1.941   Cond. No.                     7.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1013.826782
# year       -0.488248
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8703B7C8>
# Text(0.5, 1.0, 'Cahors')
# ====FOR REGION Castillon Côtes de Bordeaux=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.165
# Method:                 Least Squares   F-statistic:                  0.006289
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.939
# Time:                        14:50:45   Log-Likelihood:                -23.495
# No. Observations:                   8   AIC:                             50.99
# Df Residuals:                       6   BIC:                             51.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -106.8216   1636.200     -0.065      0.950   -4110.459    3896.816
# year           0.0645      0.813      0.079      0.939      -1.925       2.054
# ==============================================================================
# Omnibus:                        1.536   Durbin-Watson:                   2.207
# Prob(Omnibus):                  0.464   Jarque-Bera (JB):                0.241
# Skew:                           0.425   Prob(JB):                        0.886
# Kurtosis:                       2.991   Cond. No.                     1.77e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -106.821605
# year       0.064476
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E88D489C8>
# Text(0.5, 1.0, 'Castillon Côtes de Bordeaux')
# ====FOR REGION Chablis=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     16.10
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):            0.00172
# Time:                        14:50:45   Log-Likelihood:                -54.385
# No. Observations:                  14   AIC:                             112.8
# Df Residuals:                      12   BIC:                             114.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5620.5442   1387.547      4.051      0.002    2597.339    8643.749
# year          -2.7712      0.691     -4.012      0.002      -4.276      -1.266
# ==============================================================================
# Omnibus:                        3.074   Durbin-Watson:                   2.352
# Prob(Omnibus):                  0.215   Jarque-Bera (JB):                1.603
# Skew:                           0.828   Prob(JB):                        0.449
# Kurtosis:                       3.048   Cond. No.                     8.20e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    5620.544193
# year       -2.771163
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E88D9F548>
# Text(0.5, 1.0, 'Chablis')
# ====FOR REGION Chambolle-Musigny=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     18.18
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):            0.00210
# Time:                        14:50:46   Log-Likelihood:                -43.419
# No. Observations:                  11   AIC:                             90.84
# Df Residuals:                       9   BIC:                             91.63
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8679.7627   2058.443     -4.217      0.002   -1.33e+04   -4023.242
# year           4.3694      1.025      4.263      0.002       2.051       6.688
# ==============================================================================
# Omnibus:                       13.198   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                7.108
# Skew:                           1.638   Prob(JB):                       0.0286
# Kurtosis:                       5.186   Cond. No.                     9.90e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -8679.762687
# year        4.369403
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E88E22748>
# Text(0.5, 1.0, 'Chambolle-Musigny')
# ====FOR REGION Champagne=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                     12.22
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):            0.00186
# Time:                        14:50:46   Log-Likelihood:                -129.03
# No. Observations:                  26   AIC:                             262.1
# Df Residuals:                      24   BIC:                             264.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6169.6550   1732.719      3.561      0.002    2593.499    9745.811
# year          -3.0271      0.866     -3.496      0.002      -4.814      -1.240
# ==============================================================================
# Omnibus:                        0.131   Durbin-Watson:                   2.234
# Prob(Omnibus):                  0.936   Jarque-Bera (JB):                0.336
# Skew:                           0.100   Prob(JB):                        0.846
# Kurtosis:                       2.481   Cond. No.                     4.91e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    6169.654986
# year       -3.027072
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8B188B88>
# Text(0.5, 1.0, 'Champagne')
# ====FOR REGION Chassagne-Montrachet=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     52.51
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):           1.65e-05
# Time:                        14:50:46   Log-Likelihood:                -41.514
# No. Observations:                  13   AIC:                             87.03
# Df Residuals:                      11   BIC:                             88.16
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5166.4928    723.401     -7.142      0.000   -6758.687   -3574.298
# year           2.6102      0.360      7.246      0.000       1.817       3.403
# ==============================================================================
# Omnibus:                        7.650   Durbin-Watson:                   1.303
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                3.904
# Skew:                           1.234   Prob(JB):                        0.142
# Kurtosis:                       4.055   Cond. No.                     8.17e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -5166.492827
# year        2.610177
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8B1D54C8>
# Text(0.5, 1.0, 'Chassagne-Montrachet')
# ====FOR REGION Chinon=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     3.378
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0959
# Time:                        14:50:46   Log-Likelihood:                -39.079
# No. Observations:                  12   AIC:                             82.16
# Df Residuals:                      10   BIC:                             83.13
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2148.3080   1156.973      1.857      0.093    -429.588    4726.204
# year          -1.0577      0.575     -1.838      0.096      -2.340       0.224
# ==============================================================================
# Omnibus:                        2.069   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.355   Jarque-Bera (JB):                0.613
# Skew:                           0.540   Prob(JB):                        0.736
# Kurtosis:                       3.245   Cond. No.                     1.17e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    2148.308014
# year       -1.057715
# dtype: float64
# ...
# Prob(Omnibus):                  0.399   Jarque-Bera (JB):                1.197
# Skew:                           0.782   Prob(JB):                        0.550
# Kurtosis:                       2.136   Cond. No.                     1.46e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    994.029793
# year      -0.486045
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F5DA508>
# Text(0.5, 1.0, 'Touraine')
# ====FOR REGION Val de Loire=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.249
# Method:                 Least Squares   F-statistic:                  0.001921
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.967
# Time:                        14:51:02   Log-Likelihood:                -15.813
# No. Observations:                   6   AIC:                             35.63
# Df Residuals:                       4   BIC:                             35.21
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -71.9280   1989.827     -0.036      0.973   -5596.574    5452.718
# year           0.0433      0.988      0.044      0.967      -2.700       2.787
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.551
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                2.086
# Skew:                           1.427   Prob(JB):                        0.352
# Kurtosis:                       3.450   Cond. No.                     2.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -71.927967
# year      0.043311
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F649808>
# Text(0.5, 1.0, 'Val de Loire')
# ====FOR REGION Vin de France=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     6.866
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0396
# Time:                        14:51:03   Log-Likelihood:                -20.975
# No. Observations:                   8   AIC:                             45.95
# Df Residuals:                       6   BIC:                             46.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3145.0284   1193.990      2.634      0.039     223.439    6066.618
# year          -1.5546      0.593     -2.620      0.040      -3.006      -0.103
# ==============================================================================
# Omnibus:                        2.251   Durbin-Watson:                   1.470
# Prob(Omnibus):                  0.325   Jarque-Bera (JB):                0.437
# Skew:                          -0.569   Prob(JB):                        0.804
# Kurtosis:                       3.126   Cond. No.                     1.77e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    3145.028417
# year       -1.554642
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F6A6748>
# Text(0.5, 1.0, 'Vin de France')
# ====FOR REGION Vin de Pays d'Oc=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     7.430
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0213
# Time:                        14:51:03   Log-Likelihood:                -22.872
# No. Observations:                  12   AIC:                             49.74
# Df Residuals:                      10   BIC:                             50.71
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -600.9785    224.420     -2.678      0.023   -1101.018    -100.939
# year           0.3051      0.112      2.726      0.021       0.056       0.555
# ==============================================================================
# Omnibus:                        1.275   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.529   Jarque-Bera (JB):                0.942
# Skew:                           0.609   Prob(JB):                        0.624
# Kurtosis:                       2.367   Cond. No.                     8.74e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -600.978457
# year       0.305127
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F6F3B88>
# Text(0.5, 1.0, "Vin de Pays d'Oc")
# ====FOR REGION Viré-Clessé=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     5.124
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.109
# Time:                        14:51:03   Log-Likelihood:                -8.4993
# No. Observations:                   5   AIC:                             21.00
# Df Residuals:                       3   BIC:                             20.22
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1414.0855    636.721     -2.221      0.113   -3440.415     612.244
# year           0.7162      0.316      2.264      0.109      -0.291       1.723
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.788
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.850
# Skew:                           0.999   Prob(JB):                        0.654
# Kurtosis:                       2.699   Cond. No.                     1.68e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -1414.08554
# year        0.71621
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F74D748>
# Text(0.5, 1.0, 'Viré-Clessé')
# ====FOR REGION Volnay=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.170
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.305
# Time:                        14:51:03   Log-Likelihood:                -48.817
# No. Observations:                  12   AIC:                             101.6
# Df Residuals:                      10   BIC:                             102.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2739.7586   2603.209     -1.052      0.317   -8540.069    3060.552
# year           1.4014      1.295      1.082      0.305      -1.485       4.288
# ==============================================================================
# Omnibus:                        1.180   Durbin-Watson:                   2.458
# Prob(Omnibus):                  0.554   Jarque-Bera (JB):                0.755
# Skew:                           0.199   Prob(JB):                        0.686
# Kurtosis:                       1.837   Cond. No.                     1.17e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -2739.758603
# year        1.401414
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F7C1A08>
# Text(0.5, 1.0, 'Volnay')
# ====FOR REGION Vosne-Romanée=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     5.064
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0482
# Time:                        14:51:04   Log-Likelihood:                -54.645
# No. Observations:                  12   AIC:                             113.3
# Df Residuals:                      10   BIC:                             114.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7543.8926   3403.253     -2.217      0.051   -1.51e+04      39.027
# year           3.8120      1.694      2.250      0.048       0.038       7.586
# ==============================================================================
# Omnibus:                        1.157   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                0.751
# Skew:                          -0.568   Prob(JB):                        0.687
# Kurtosis:                       2.538   Cond. No.                     9.41e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -7543.892621
# year        3.811951
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F803688>
# Text(0.5, 1.0, 'Vosne-Romanée')
# ====FOR REGION Vouvray=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.513
# Method:                 Least Squares   F-statistic:                     14.68
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):            0.00239
# Time:                        14:51:04   Log-Likelihood:                -57.362
# No. Observations:                  14   AIC:                             118.7
# Df Residuals:                      12   BIC:                             120.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6154.3162   1597.966      3.851      0.002    2672.647    9635.985
# year          -3.0478      0.795     -3.832      0.002      -4.781      -1.315
# ==============================================================================
# Omnibus:                        0.140   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.932   Jarque-Bera (JB):                0.160
# Skew:                           0.159   Prob(JB):                        0.923
# Kurtosis:                       2.584   Cond. No.                     7.64e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.64e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    6154.316204
# year       -3.047817
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F882E48>
# Text(0.5, 1.0, 'Vouvray')

# %% [markdown]
# Remarks: This is a regression on each region and the price only. Other variables such as winery or variety are not yet included.

# %% [markdown]
# ## Italy: Region and Price distribution

# %%
# Italy region distribution that has price feature available. This using the price data only. 

italy = data_price_df[data_price_df['country'] == 'Italy']
print('Shape of Italy DataSet: ', italy.shape)
count_italy_price = pd.DataFrame(italy.groupby('region_1')['region_1'].count())
count_italy_price['region_1'].describe()
# Out:
# Shape of Italy DataSet:  (16074, 15)
# count     367.000000
# mean       43.798365
# std       139.840689
# min         1.000000
# 25%         3.000000
# 50%         7.000000
# 75%        25.500000
# max      1360.000000
# Name: region_1, dtype: float64

# %% [markdown]
# Remarks: Getting the 75% and above

# %%
# boxplot
boxplot_italy = count_italy_price.boxplot(column = 'region_1', figsize = (5,8))

# %%
# filter price data on France 
italy = data_price_df[data_price_df['country'] == 'Italy']
# get the region that got >= 9 and put it in a list 
count_italy_price = pd.DataFrame(italy.groupby('region_1')['region_1'].count())
italy_regions_list = count_italy_price[count_italy_price['region_1'] >= 25].index.tolist()
# filter the france dataset on that list 
italy = italy[italy['region_1'].isin(italy_regions_list)]


# groupby per region, get the years and the price
price_year_per_region = italy.groupby(['region_1','years'])['years','price'].agg(['count','min','max', 'mean']).reset_index().set_index('region_1')
# perform regression on years and price on that region ( use the mean for years and mean for price)

italy_list_region = list(price_year_per_region.index.unique())

for region in italy_list_region:
    print(f'====FOR REGION {region}=====')
    regression(region, price_year_per_region)
# Out:
# ====FOR REGION Aglianico del Vulture=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     23.59
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):           0.000505
# Time:                        14:51:24   Log-Likelihood:                -42.806
# No. Observations:                  13   AIC:                             89.61
# Df Residuals:                      11   BIC:                             90.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5153.8540   1054.433      4.888      0.000    2833.063    7474.645
# year          -2.5490      0.525     -4.857      0.001      -3.704      -1.394
# ==============================================================================
# Omnibus:                        0.454   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.537
# Skew:                          -0.245   Prob(JB):                        0.765
# Kurtosis:                       2.133   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    5153.853988
# year       -2.548965
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8AED6C88>
# Text(0.5, 1.0, 'Aglianico del Vulture')
# ====FOR REGION Alto Adige=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     5.678
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0299
# Time:                        14:51:24   Log-Likelihood:                -74.481
# No. Observations:                  18   AIC:                             153.0
# Df Residuals:                      16   BIC:                             154.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2943.7505   1221.899      2.409      0.028     353.441    5534.060
# year          -1.4508      0.609     -2.383      0.030      -2.741      -0.160
# ==============================================================================
# Omnibus:                        4.945   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                2.633
# Skew:                           0.537   Prob(JB):                        0.268
# Kurtosis:                       4.536   Cond. No.                     6.47e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.47e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    2943.750491
# year       -1.450793
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8AF1C948>
# Text(0.5, 1.0, 'Alto Adige')
# ====FOR REGION Alto Adige Valle Isarco=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     7.075
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0763
# Time:                        14:51:24   Log-Likelihood:                -12.650
# No. Observations:                   5   AIC:                             29.30
# Df Residuals:                       3   BIC:                             28.52
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6664.0061   2496.340      2.670      0.076   -1280.462    1.46e+04
# year          -3.2985      1.240     -2.660      0.076      -7.245       0.648
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.725
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.479
# Skew:                           0.046   Prob(JB):                        0.787
# Kurtosis:                       1.486   Cond. No.                     2.87e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    6664.006061
# year       -3.298485
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8AF79248>
# Text(0.5, 1.0, 'Alto Adige Valle Isarco')
# ====FOR REGION Amarone della Valpolicella=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     6.166
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0304
# Time:                        14:51:25   Log-Likelihood:                -64.975
# No. Observations:                  13   AIC:                             134.0
# Df Residuals:                      11   BIC:                             135.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.135e+04   4534.932      2.503      0.029    1371.250    2.13e+04
# year          -5.6122      2.260     -2.483      0.030     -10.587      -0.638
# ==============================================================================
# Omnibus:                        1.986   Durbin-Watson:                   1.350
# Prob(Omnibus):                  0.370   Jarque-Bera (JB):                1.233
# Skew:                           0.732   Prob(JB):                        0.540
# Kurtosis:                       2.636   Cond. No.                     8.42e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    11352.568264
# year        -5.612219
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8AFEB0C8>
# Text(0.5, 1.0, 'Amarone della Valpolicella')
# ====FOR REGION Amarone della Valpolicella Classico=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                   0.01125
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.917
# Time:                        14:51:25   Log-Likelihood:                -75.595
# No. Observations:                  18   AIC:                             155.2
# Df Residuals:                      16   BIC:                             157.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -92.0635   1558.142     -0.059      0.954   -3395.178    3211.051
# year           0.0824      0.777      0.106      0.917      -1.565       1.730
# ==============================================================================
# Omnibus:                        7.129   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                4.279
# Skew:                           1.030   Prob(JB):                        0.118
# Kurtosis:                       4.209   Cond. No.                     7.74e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.74e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -92.063548
# year      0.082432
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8FD53D88>
# Text(0.5, 1.0, 'Amarone della Valpolicella Classico')
# ====FOR REGION Barbaresco=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     2.339
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.152
# Time:                        14:51:25   Log-Likelihood:                -54.015
# No. Observations:                  14   AIC:                             112.0
# Df Residuals:                      12   BIC:                             113.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2255.4683   1435.659      1.571      0.142    -872.563    5383.500
# year          -1.0939      0.715     -1.529      0.152      -2.652       0.465
# ==============================================================================
# Omnibus:                        6.042   Durbin-Watson:                   1.488
# Prob(Omnibus):                  0.049   Jarque-Bera (JB):                2.793
# Skew:                           0.882   Prob(JB):                        0.247
# Kurtosis:                       4.295   Cond. No.                     8.71e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    2255.468291
# year       -1.093946
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8FDBA648>
# Text(0.5, 1.0, 'Barbaresco')
# ====FOR REGION Barbera d'Alba=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     2.136
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.170
# Time:                        14:51:25   Log-Likelihood:                -38.886
# No. Observations:                  14   AIC:                             81.77
# Df Residuals:                      12   BIC:                             83.05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        843.7172    559.911      1.507      0.158    -376.225    2063.659
# year          -0.4072      0.279     -1.462      0.170      -1.014       0.200
# ==============================================================================
# Omnibus:                        4.069   Durbin-Watson:                   1.434
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                1.702
# Skew:                           0.788   Prob(JB):                        0.427
# Kurtosis:                       3.661   Cond. No.                     1.00e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    843.717207
# year      -0.407222
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8FE180C8>
# Text(0.5, 1.0, "Barbera d'Alba")
# ====FOR REGION Barbera d'Alba Superiore=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     2.027
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.188
# Time:                        14:51:26   Log-Likelihood:                -31.377
# No. Observations:                  11   AIC:                             66.75
# Df Residuals:                       9   BIC:                             67.55
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1048.3294    753.448     -1.391      0.198   -2752.748     656.089
# year           0.5341      0.375      1.424      0.188      -0.314       1.383
# ==============================================================================
# Omnibus:                        2.610   Durbin-Watson:                   2.188
# Prob(Omnibus):                  0.271   Jarque-Bera (JB):                1.064
# Skew:                           0.761   Prob(JB):                        0.587
# Kurtosis:                       3.041   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -1048.329365
# year        0.534127
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8FE72888>
# Text(0.5, 1.0, "Barbera d'Alba Superiore")
# ====FOR REGION Barbera d'Asti=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.071
# Method:                 Least Squares   F-statistic:                    0.1373
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.717
# Time:                        14:51:26   Log-Likelihood:                -44.861
# No. Observations:                  14   AIC:                             93.72
# Df Residuals:                      12   BIC:                             95.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        314.6881    789.111      0.399      0.697   -1404.637    2034.013
# year          -0.1455      0.393     -0.371      0.717      -1.001       0.710
# ==============================================================================
# Omnibus:                        1.706   Durbin-Watson:                   1.229
# Prob(Omnibus):                  0.426   Jarque-Bera (JB):                0.812
# Skew:                           0.589   Prob(JB):                        0.666
# Kurtosis:                       2.925   Cond. No.                     9.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    314.688063
# year      -0.145534
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8FF652C8>
# Text(0.5, 1.0, "Barbera d'Asti")
# ====FOR REGION Barbera d'Asti Superiore=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     1.968
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.191
# Time:                        14:51:26   Log-Likelihood:                -41.180
# No. Observations:                  12   AIC:                             86.36
# Df Residuals:                      10   BIC:                             87.33
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1830.4104   1283.660      1.426      0.184   -1029.762    4690.582
# year          -0.8961      0.639     -1.403      0.191      -2.320       0.527
# ==============================================================================
# Omnibus:                        1.162   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                0.162
# Skew:                           0.273   Prob(JB):                        0.922
# Kurtosis:                       3.162   Cond. No.                     1.09e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1830.410399
# year       -0.896110
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8FFC9888>
# Text(0.5, 1.0, "Barbera d'Asti Superiore")
# ====FOR REGION Barolo=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     1.664
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.217
# Time:                        14:51:26   Log-Likelihood:                -68.240
# No. Observations:                  17   AIC:                             140.5
# Df Residuals:                      15   BIC:                             142.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1596.9377   1295.109     -1.233      0.237   -4357.398    1163.522
# year           0.8333      0.646      1.290      0.217      -0.544       2.210
# ==============================================================================
# Omnibus:                        1.992   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                0.702
# Skew:                           0.465   Prob(JB):                        0.704
# Kurtosis:                       3.355   Cond. No.                     7.50e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -1596.937664
# year        0.833255
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E9006A548>
# Text(0.5, 1.0, 'Barolo')
# ====FOR REGION Bolgheri=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.052
# Method:                 Least Squares   F-statistic:                    0.1652
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.690
# Time:                        14:51:27   Log-Likelihood:                -87.475
# No. Observations:                  18   AIC:                             178.9
# Df Residuals:                      16   BIC:                             180.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -110.8458    392.465     -0.282      0.781    -942.834     721.142
# year           0.0800      0.197      0.406      0.690      -0.337       0.497
# ==============================================================================
# Omnibus:                       20.943   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.150
# Skew:                           2.091   Prob(JB):                     9.40e-06
# Kurtosis:                       6.658   Cond. No.                     1.00e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -110.845786
# year       0.080001
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E900BEFC8>
# Text(0.5, 1.0, 'Bolgheri')
# ====FOR REGION Bolgheri Superiore=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     1.764
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.211
# Time:                        14:51:27   Log-Likelihood:                -55.100
# No. Observations:                  13   AIC:                             114.2
# Df Residuals:                      11   BIC:                             115.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -276.1573    269.064     -1.026      0.327    -868.363     316.048
# year           0.1789      0.135      1.328      0.211      -0.118       0.475
# ==============================================================================
# Omnibus:                        2.306   Durbin-Watson:                   2.324
# Prob(Omnibus):                  0.316   Jarque-Bera (JB):                0.537
# Skew:                           0.401   Prob(JB):                        0.765
# Kurtosis:                       3.589   Cond. No.                     1.06e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -276.157255
# year       0.178891
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E90122608>
# Text(0.5, 1.0, 'Bolgheri Superiore')
# ====FOR REGION Brunello di Montalcino=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.078
# Method:                 Least Squares   F-statistic:                   0.05475
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.819
# Time:                        14:51:27   Log-Likelihood:                -63.993
# No. Observations:                  14   AIC:                             132.0
# Df Residuals:                      12   BIC:                             133.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -547.9364   2667.218     -0.205      0.841   -6359.305    5263.432
# year           0.3113      1.330      0.234      0.819      -2.587       3.210
# ==============================================================================
# Omnibus:                       28.168   Durbin-Watson:                   2.439
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.550
# Skew:                           2.575   Prob(JB):                     1.16e-08
# Kurtosis:                       9.012   Cond. No.                     7.92e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.92e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -547.936437
# year       0.311298
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E90180F08>
# Text(0.5, 1.0, 'Brunello di Montalcino')
# ====FOR REGION Campania=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     1.610
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.240
# Time:                        14:51:27   Log-Likelihood:                -40.975
# No. Observations:                  10   AIC:                             85.95
# Df Residuals:                       8   BIC:                             86.55
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4353.9388   3404.096      1.279      0.237   -3495.920    1.22e+04
# year          -2.1495      1.694     -1.269      0.240      -6.056       1.757
# ==============================================================================
# Omnibus:                        2.245   Durbin-Watson:                   2.183
# Prob(Omnibus):                  0.325   Jarque-Bera (JB):                1.331
# Skew:                           0.660   Prob(JB):                        0.514
# Kurtosis:                       1.796   Cond. No.                     1.33e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    4353.938840
# year       -2.149482
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E901EA288>
# Text(0.5, 1.0, 'Campania')
# ====FOR REGION Cannonau di Sardegna=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     1.219
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.298
# Time:                        14:51:28   Log-Likelihood:                -39.049
# No. Observations:                  11   AIC:                             82.10
# Df Residuals:                       9   BIC:                             82.89
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1240.2654   1146.455     -1.082      0.307   -3833.726    1353.195
# year           0.6303      0.571      1.104      0.298      -0.661       1.922
# ==============================================================================
# Omnibus:                        0.879   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.644   Jarque-Bera (JB):                0.727
# Skew:                           0.509   Prob(JB):                        0.695
# Kurtosis:                       2.258   Cond. No.                     8.20e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -1240.265448
# year        0.630326
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E90241E88>
# Text(0.5, 1.0, 'Cannonau di Sardegna')
# ====FOR REGION Castel del Monte=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1.362
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.273
# Time:                        14:51:28   Log-Likelihood:                -39.849
# No. Observations:                  11   AIC:                             83.70
# Df Residuals:                       9   BIC:                             84.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1952.9901   1652.190      1.182      0.267   -1784.523    5690.503
# year          -0.9600      0.823     -1.167      0.273      -2.821       0.901
# ==============================================================================
# Omnibus:                        2.280   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                0.960
# Skew:                           0.221   Prob(JB):                        0.619
# Kurtosis:                       1.622   Cond. No.                     1.10e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    1952.990143
# year       -0.959980
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E902A9308>
# Text(0.5, 1.0, 'Castel del Monte')
# ====FOR REGION Chianti=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.051
# Method:                 Least Squares   F-statistic:                    0.2273
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.640
# Time:                        14:51:28   Log-Likelihood:                -56.194
# No. Observations:                  17   AIC:                             116.4
# Df Residuals:                      15   BIC:                             118.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.7026    178.803      0.563      0.582    -280.408     481.813
# year          -0.0426      0.089     -0.477      0.640      -0.233       0.148
# ==============================================================================
# Omnibus:                       24.115   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.492
# Skew:                           2.132   Prob(JB):                     5.34e-08
# Kurtosis:                       8.394   Cond. No.                     2.10e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    100.702595
# year      -0.042582
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E90300DC8>
# Text(0.5, 1.0, 'Chianti')
# ====FOR REGION Chianti Classico=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     1.450
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.244
# Time:                        14:51:28   Log-Likelihood:                -67.774
# No. Observations:                  20   AIC:                             139.5
# Df Residuals:                      18   BIC:                             141.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -634.4163    549.431     -1.155      0.263   -1788.728     519.896
# year           0.3300      0.274      1.204      0.244      -0.246       0.906
# ==============================================================================
# Omnibus:                        3.256   Durbin-Watson:                   0.681
# Prob(Omnibus):                  0.196   Jarque-Bera (JB):                1.430
# Skew:                          -0.253   Prob(JB):                        0.489
# Kurtosis:                       1.792   Cond. No.                     6.52e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -634.416310
# year       0.330002
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E90386FC8>
# Text(0.5, 1.0, 'Chianti Classico')
# ====FOR REGION Chianti Colli Senesi=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                    0.3558
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.564
# Time:                        14:51:29   Log-Likelihood:                -34.138
# No. Observations:                  12   AIC:                             72.28
# Df Residuals:                      10   BIC:                             73.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         86.5481    116.475      0.743      0.475    -172.974     346.070
# year          -0.0347      0.058     -0.597      0.564      -0.164       0.095
# ==============================================================================
# Omnibus:                        1.229   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.541   Jarque-Bera (JB):                0.562
# Skew:                           0.520   Prob(JB):                        0.755
# Kurtosis:                       2.791   Cond. No.                     1.77e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    86.548089
# year     -0.034691
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E903F10C8>
# Text(0.5, 1.0, 'Chianti Colli Senesi')
# ====FOR REGION Chianti Rufina=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.088
# Method:                 Least Squares   F-statistic:                   0.02554
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.876
# Time:                        14:51:29   Log-Likelihood:                -47.583
# No. Observations:                  13   AIC:                             99.17
# Df Residuals:                      11   BIC:                             100.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.9134   1211.801     -0.139      0.892   -2836.069    2498.243
# year           0.0964      0.603      0.160      0.876      -1.231       1.424
# ==============================================================================
# Omnibus:                        7.920   Durbin-Watson:                   0.888
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                3.975
# Skew:                           1.186   Prob(JB):                        0.137
# Kurtosis:                       4.310   Cond. No.                     8.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const   -168.913428
# year       0.096421
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E9044C888>
# Text(0.5, 1.0, 'Chianti Rufina')
# ====FOR REGION Colli Orientali del Friuli=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     1.437
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.258
# Time:                        14:51:29   Log-Likelihood:                -46.725
# No. Observations:                  12   AIC:                             97.45
# Df Residuals:                      10   BIC:                             98.42
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2376.5615   1956.436      1.215      0.252   -1982.649    6735.772
# year          -1.1683      0.975     -1.199      0.258      -3.340       1.003
# ==============================================================================
# Omnibus:                        4.884   Durbin-Watson:                   2.069
# Prob(Omnibus):                  0.087   Jarque-Bera (JB):                1.972
# Skew:                           0.927   Prob(JB):                        0.373
# Kurtosis:                       3.712   Cond. No.                     1.05e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ...
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    578.901089
# year      -0.275613
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8DF9C288>
# Text(0.5, 1.0, 'Verdicchio dei Castelli di Jesi Classico')
# ====FOR REGION Verdicchio dei Castelli di Jesi Classico Superiore=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.089
# Method:                 Least Squares   F-statistic:                    0.1045
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.753
# Time:                        14:51:46   Log-Likelihood:                -35.008
# No. Observations:                  12   AIC:                             74.02
# Df Residuals:                      10   BIC:                             74.99
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        260.4826    732.160      0.356      0.729   -1370.872    1891.837
# year          -0.1178      0.364     -0.323      0.753      -0.930       0.694
# ==============================================================================
# Omnibus:                        0.773   Durbin-Watson:                   2.582
# Prob(Omnibus):                  0.679   Jarque-Bera (JB):                0.622
# Skew:                          -0.139   Prob(JB):                        0.733
# Kurtosis:                       1.920   Cond. No.                     1.04e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    260.482630
# year      -0.117781
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86440F48>
# Text(0.5, 1.0, 'Verdicchio dei Castelli di Jesi Classico Superiore')
# ====FOR REGION Vermentino di Sardegna=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     1.496
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.267
# Time:                        14:51:46   Log-Likelihood:                -24.852
# No. Observations:                   8   AIC:                             53.70
# Df Residuals:                       6   BIC:                             53.86
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2013.7247   1627.666      1.237      0.262   -1969.030    5996.480
# year          -0.9900      0.809     -1.223      0.267      -2.970       0.990
# ==============================================================================
# Omnibus:                        6.231   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                1.993
# Skew:                           1.196   Prob(JB):                        0.369
# Kurtosis:                       3.507   Cond. No.                     1.48e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    2013.724690
# year       -0.989996
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E86FDCF88>
# Text(0.5, 1.0, 'Vermentino di Sardegna')
# ====FOR REGION Vernaccia di San Gimignano=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.076
# Method:                 Least Squares   F-statistic:                   0.01152
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.916
# Time:                        14:51:46   Log-Likelihood:                -45.405
# No. Observations:                  15   AIC:                             94.81
# Df Residuals:                      13   BIC:                             96.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.2110    135.696      0.259      0.799    -257.941     328.363
# year          -0.0073      0.068     -0.107      0.916      -0.154       0.139
# ==============================================================================
# Omnibus:                        1.515   Durbin-Watson:                   1.358
# Prob(Omnibus):                  0.469   Jarque-Bera (JB):                1.164
# Skew:                           0.622   Prob(JB):                        0.559
# Kurtosis:                       2.438   Cond. No.                     1.96e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.96e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    35.211020
# year     -0.007268
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8E96E4C8>
# Text(0.5, 1.0, 'Vernaccia di San Gimignano')
# ====FOR REGION Veronese=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     6.098
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0312
# Time:                        14:51:47   Log-Likelihood:                -56.178
# No. Observations:                  13   AIC:                             116.4
# Df Residuals:                      11   BIC:                             117.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7327.3397   2949.467      2.484      0.030     835.607    1.38e+04
# year          -3.6255      1.468     -2.469      0.031      -6.857      -0.394
# ==============================================================================
# Omnibus:                        4.288   Durbin-Watson:                   2.215
# Prob(Omnibus):                  0.117   Jarque-Bera (JB):                1.968
# Skew:                           0.930   Prob(JB):                        0.374
# Kurtosis:                       3.414   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    7327.339744
# year       -3.625458
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8EC19948>
# Text(0.5, 1.0, 'Veronese')
# ====FOR REGION Vigneti delle Dolomiti=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     20.88
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):           0.000526
# Time:                        14:51:47   Log-Likelihood:                -57.722
# No. Observations:                  15   AIC:                             119.4
# Df Residuals:                      13   BIC:                             120.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6550.1911   1426.147      4.593      0.001    3469.189    9631.193
# year          -3.2442      0.710     -4.570      0.001      -4.778      -1.711
# ==============================================================================
# Omnibus:                       13.926   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               10.541
# Skew:                          -1.550   Prob(JB):                      0.00514
# Kurtosis:                       5.693   Cond. No.                     9.10e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    6550.191093
# year       -3.244224
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8F8C9F08>
# Text(0.5, 1.0, 'Vigneti delle Dolomiti')
# ====FOR REGION Vino Nobile di Montepulciano=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.308
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     4.890
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):             0.0491
# Time:                        14:51:47   Log-Likelihood:                -48.301
# No. Observations:                  13   AIC:                             100.6
# Df Residuals:                      11   BIC:                             101.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3160.9311   1409.213      2.243      0.046      59.275    6262.588
# year          -1.5529      0.702     -2.211      0.049      -3.099      -0.007
# ==============================================================================
# Omnibus:                        1.722   Durbin-Watson:                   2.422
# Prob(Omnibus):                  0.423   Jarque-Bera (JB):                0.196
# Skew:                           0.070   Prob(JB):                        0.907
# Kurtosis:                       3.585   Cond. No.                     9.44e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    3160.931074
# year       -1.552867
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8D905CC8>
# Text(0.5, 1.0, 'Vino Nobile di Montepulciano')
# ====FOR REGION Vino Spumante=====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             price_mean   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                 -0.075
# Method:                 Least Squares   F-statistic:                    0.3695
# Date:                Wed, 10 Jun 2020   Prob (F-statistic):              0.560
# Time:                        14:51:47   Log-Likelihood:                -24.586
# No. Observations:                  10   AIC:                             53.17
# Df Residuals:                       8   BIC:                             53.78
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        413.0006    623.016      0.663      0.526   -1023.677    1849.678
# year          -0.1884      0.310     -0.608      0.560      -0.903       0.526
# ==============================================================================
# Omnibus:                        0.552   Durbin-Watson:                   1.584
# Prob(Omnibus):                  0.759   Jarque-Bera (JB):                0.562
# Skew:                           0.338   Prob(JB):                        0.755
# Kurtosis:                       2.055   Cond. No.                     1.25e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# =====Result Parameters========
# const    413.000583
# year      -0.188391
# dtype: float64
# <seaborn.axisgrid.FacetGrid object at 0x0000025E8DE709C8>
# Text(0.5, 1.0, 'Vino Spumante')

# %% [markdown]
# Remarks: Find the average slope in each region irregardless of how old the wine is.
#     (observation: The more negative the correlation is meaning, the wines shows that it 'ages' well because the old wines gets expensive)
#     This means that this region is producing fine wines over the years.

# %% [markdown]
# ## Spain: Region and Price distribution

# %%
# Italy region distribution that has price feature available. This using the price data only. 

spain = data_price_df[data_price_df['country'] == 'Spain']
print('Shape of Spain DataSet: ', italy.shape)
count_spain_price = pd.DataFrame(spain.groupby('region_1')['region_1'].count())
count_spain_price['region_1'].describe()

# %%
# boxplot
boxplot_spain = count_spain_price.boxplot(column = 'region_1', figsize = (5,8))

# %%
# filter price data on spain country only
spain = data_price_df[data_price_df['country'] == 'Spain']
# get the region that got >= 9 and put it in a list 
count_spain_price = pd.DataFrame(spain.groupby('region_1')['region_1'].count())
spain_regions_list = count_spain_price[count_spain_price['region_1'] >= 70].index.tolist()
# filter the france dataset on that list 
spain = spain[spain['region_1'].isin(spain_regions_list)]


# groupby per region, get the years and the price
price_year_per_region = spain.groupby(['region_1','years'])['years','price'].agg(['count','min','max', 'mean']).reset_index().set_index('region_1')
# perform regression on years and price on that region ( use the mean for years and mean for price)

spain_list_region = list(price_year_per_region.index.unique())

for region in spain_list_region:
    print(f'====FOR REGION {region}=====')
    regression(region, price_year_per_region)

# %% [markdown]
# Remarks: Next move is clustering these time series.

# %% [markdown]
# ## EDA about regions and points
#
# - The points variable is important to have since this can be indication of the quality of the wine on that year per region. <br>
# - In this EDA we are going to use the 'final_data'

# %%
sns.countplot(final_data['points'])

# %%
# descriptive analysis of years per country
final_data.groupby('country')['points'].agg(['count','min','max', 'mean'])

# %% [markdown]
# ## France: Region and points Distribution

# %%
france = final_data[final_data['country'] == 'France']
print('Shape of France DataSet: ', france.shape)
count_france_price = pd.DataFrame(france.groupby('region_1')['region_1'].count())
count_france_price['region_1'].describe()

# %%
boxplot_france = count_france_price.boxplot(column = 'region_1', figsize = (5,8))

# %% [markdown]
# Remarks: There are more data here compared to the other dataset that was used for the price analysis.

# %%
# filter price data on France 
france_points = final_data[final_data['country'] == 'France']
# get the region that got >= 9 and put it in a list 
count_france_price = pd.DataFrame(france_points.groupby('region_1')['region_1'].count())
france_regions_list = count_france_price[count_france_price['region_1'] >= 37].index.tolist() # 75 percentile and above
# filter the france dataset on that list 
france_points = france[france['region_1'].isin(france_regions_list)]

# %%
# function on regression on years vs points per region

def regression_on_points(region, price_per_year_df):
    x = pd.DataFrame(price_per_year_df.loc[str(region)]['years']['mean'].values).rename(columns = {0:'year'})
    y = pd.DataFrame(price_per_year_df.loc[str(region)]['points']['mean'].values).rename(columns = {0:'points_mean'}) # this is the y-axis 
    points_df = pd.concat([x,y], axis = 1) # save this dataframe for future use. 
    x = sm.add_constant(x)
    model = sm.OLS(y,x)
    results = model.fit()
    print(results.summary())
    print(sns.lmplot(x='year', y='points_mean', data=points_df))
    ax = plt.gca()
    print(ax.set_title(f"{region}"))

# %%
# groupby per region, get the years and the points
points_year_per_region = france_points.groupby(['region_1','years'])['years','points'].agg(['count','min','max', 'mean']).reset_index().set_index('region_1')
# perform regression on years and price on that region ( use the mean for years and mean for price)

france_list_region = list(points_year_per_region.index.unique())

for region in france_list_region: # make this as a function. 
    print(f'====FOR REGION {region}=====')
    regression_on_points(region,points_year_per_region)

# %% [markdown]
# ## Italy: Region and points Distribution

# %%
italy_points = final_data[final_data['country'] == 'Italy']
print('Shape of France DataSet: ', italy_points.shape)
count_italy_points = pd.DataFrame(italy_points.groupby('region_1')['region_1'].count())
print(count_italy_points['region_1'].describe())

boxplot_italy = count_italy_points.boxplot(column = 'region_1', figsize = (5,8))

# %% [markdown]
# Remarks: 75 percentile and above will considered in the regression

# %%
# get the region that got >= 9 and put it in a list 
italy_regions_list = count_italy_points[count_italy_points['region_1'] >= 26].index.tolist()
# filter the france dataset on that list 
italy_points = italy_points[italy_points['region_1'].isin(italy_regions_list)]

# groupby per region, get the years and the points
points_year_per_region = italy_points.groupby(['region_1','years'])['years','points'].agg(['count','min','max', 'mean']).reset_index().set_index('region_1')
# perform regression on years and price on that region ( use the mean for years and mean for price)

italy_list_region = list(points_year_per_region.index.unique())

for region in italy_list_region: # make this as a function. 
    print(f'====FOR REGION {region}=====')
    regression_on_points(region, points_year_per_region)

# %% [markdown]
# ## Spain: Region and points Distribution

# %%
spain_points = final_data[final_data['country'] == 'Spain']
print('Shape of Spain DataSet: ', spain_points.shape)
count_spain_points = pd.DataFrame(spain_points.groupby('region_1')['region_1'].count())
print(count_spain_points['region_1'].describe())

boxplot_spain = count_spain_points.boxplot(column = 'region_1', figsize = (5,8))

# %%
spain_regions_list = count_spain_points[count_spain_points['region_1'] >= 71].index.tolist()
# filter the france dataset on that list 
spain_points = spain_points[spain_points['region_1'].isin(spain_regions_list)]

# groupby per region, get the years and the price
points_year_per_region = spain_points.groupby(['region_1','years'])['years','points'].agg(['count','min','max', 'mean']).reset_index().set_index('region_1')
# perform regression on years and price on that region ( use the mean for years and mean for price)

spain_list_region = list(points_year_per_region.index.unique())

for region in spain_list_region: # make this as a function. 
    print(f'====FOR REGION {region}=====')
    regression_on_points(region, points_year_per_region)

# %% [markdown]
# # WITH GRAPE VARIETY

# %% [markdown]
# # France Regression on Price, Points and Year based on Grape Variety
#
# #### The data I will use for this is the "data_price_df".

# %%
minimum_count_per_region = 10

# %%
# Analysis with variety included

# checking the distribution of the variety per region
france_var = data_price_df[data_price_df['country'] == 'France']
fran_variety_year_per_region = france_var.groupby(['region_1','variety'])['years'].agg(['count'])

# %%
#check the distribution of the variety in each region 
fran_variety_year_per_region['count'].describe()#.loc[['Alsace','variety']].describe() # this is an example with the region 'Alsace' and from here I will check the distribution of the count per region

# %%
boxplot_france = fran_variety_year_per_region.boxplot(column = 'count', figsize = (5,8))

# %% [markdown]
# Remarks: 9 is very small for this very skewed distribution, therefore, I am going to set a manual threshold of 25 to filter out the regions that have very small records in each variety.

# %%
fran_variety_year_per_region = fran_variety_year_per_region[fran_variety_year_per_region['count'] >= minimum_count_per_region].reset_index().set_index('region_1')

# %%
# snippet from the 1 region

fran_variety_year_per_region.loc['Alsace']

# %%
# this function is going to apply regression based on years, price in each variety per region. 

def results_summary_to_dataframe(results):
    '''take the result of an statsmodel results table and transforms it into a dataframe'''
    #pvals = results.pvalues
    #print('pvals aaaaaaaaaaaaaaaaaaa:',pvals)
    pvals_cons = results.pvalues[0]
    print('pvals cons:',pvals_cons)
    pvals_year = results.pvalues[1]
    print('pvals year:',pvals_year)
    pvals_points = results.pvalues[2]
    print('pvals points:',pvals_points)
    coeff1 = results.params[1]
    coeff2 = results.params[2]
    print('The coeff1: ',coeff1)
    print('The coeff2: ',coeff2)
    #conf_lower = results.conf_int()[0]
    #conf_higher = results.conf_int()[1]
    r = results.rsquared
    print('the R', r)

    results_df = pd.DataFrame({#"p-value_cons":pvals_cons,
                               "p-value-year":pvals_year,
                               "p-value-points":pvals_points,
                               "coefficient_years":coeff1,
                               "coefficient_points":coeff2,
                               #"conf_lower":conf_lower,
                               #"conf_higher":conf_higher,
                               "R-squared":r
                                },index=[0])

    #Reordering...
    results_df = results_df[["coefficient_years","coefficient_points","p-value-year","p-value-points","R-squared"]] # ,"conf_lower","conf_higher"
    return results_df



def show_plot(country_df,region,list_var):
    '''This function shows the plot and get the p-value, and R-squared'''
    varieties = list_var
    print(varieties)
    df = country_df[(country_df['region_1'] == str(region))&(country_df['variety'].isin(varieties))]
    df = df.groupby(['region_1','variety','years'])['years','price', 'points'].agg(['count', 'mean']).reset_index().set_index('region_1')
    df.reset_index(inplace = True)
    df.columns = df.columns.get_level_values(0)
    #print('11111111111111111111111111')
    #display(df)
    df.columns = ['region', 'variety','year','year_count','year_mean','price_count','price_mean', 'points_count','points_mean']
    #print('222222222222222222222222222')
    #display(df)
    #print(f'The whole dataframe of{}')
    #display(df)
    # filter the dataframe per variety using a for loop 
    final_df = pd.DataFrame({'region':[],'grape_variety':[], 'coefficient_years':[],'coefficient_points':[],'p-value-year':[],'p-value-points':[],'R-squared':[]}) # , 'conf_low':[], 'conf_high':[]
    for var in varieties:
        # print('vaaaaaaaaaar',var)
        variety_df = df[df['variety'] == str(var)] # this will filter the dataframe per variety per region
        # print('The Variety DF=======================')
        # print('VARIETY SHAPE:',variety_df.shape)
        display(variety_df)
        print('++++++++++++++++++++++++++++++++++++++++')
        # if variety_df has more rows.
        if variety_df.shape[0] > 3:
            # print(sns.lmplot(x='year', y='price_mean', data=variety_df, size = 8)) #
            plt.subplots_adjust(hspace = 0.5)
            plt.legend()
            X = variety_df[['year', 'points_mean']] # independent
            Y = variety_df['price_mean'] # dependent variable
            x = sm.add_constant(X)
            model = sm.OLS(Y,x)
            results = model.fit()
            #print(results.summary())
            # print('Printing parameters')
            #print(results.params)
            ax = plt.gca()
            ax.set_title(f"{region},{var}")
            results_df = results_summary_to_dataframe(results)
            # print('##############################')
            #display(results_df)
            for index, row in results_df.iterrows():
                p_value_year = row['p-value-year']
                p_value_points = row['p-value-points']
                r_squared = row['R-squared']
                coeff_year = row['coefficient_years']
                coeff_points = row['coefficient_points']
                #conf_low = row['conf_lower']
                #conf_high = row['conf_higher']
                final_df = final_df.append({'region':region,'grape_variety':var,'coefficient_years':coeff_year,'coefficient_points':coeff_points, 'p-value-year':p_value_year,
                                            'p-value-points':p_value_points,'R-squared':r_squared},ignore_index = True) #, 'conf_low':conf_low, 'conf_high':conf_high
        else:
            # print('ARRRRGGGGGG')
            continue

    return final_df

# %%
def get_france_classified_regions():
    france_region = fran_variety_year_per_region.index.tolist()
    myFrancelist = set(france_region)
    myFrancelist = list(myFrancelist)

    appended_dfs = []
    for region in myFrancelist:
        # print(f'===================={region}==========================')
        try:
            varieties = list(fran_variety_year_per_region.loc[str(region)]['variety'].values)
            summary_stat_france = show_plot(france_var,region,varieties) ## append this df to another df. 
            appended_dfs.append(summary_stat_france)
        except:
            variety = pd.DataFrame(fran_variety_year_per_region.loc[str(region)]).transpose()['variety'].values
            summary_stat_france2 = (show_plot(france_var,region, variety))
            appended_dfs.append(summary_stat_france2)



    france_classified_regions = pd.concat(appended_dfs)
    france_classified_regions['country'] = 'France'
    france_classified_regions['classification'] = np.where((france_classified_regions['coefficient_years'] < 0) & (france_classified_regions['p-value-year'] < 0.05) , 'appreciating', 'depreciating')
    print(france_classified_regions.shape)
    
france_classified_regions = get_france_classified_regions()

# %% [markdown]
# # Italy Regression on Price, Points and Year based on Grape Variety
#
# #### The data I will use for this is the "data_price_df".

# %% [markdown]
# Remarks: Based on the distribution, I will set a manual threshold of 25 or 10 for regression.

# %%
# Analysis with variety included

# checking the distribution of the variety per region
italy_var = data_price_df[data_price_df['country'] == 'Italy']
italy_variety_year_per_region = italy_var.groupby(['region_1','variety'])['years'].agg(['count'])

# %%
#check the distribution of the variety in each region 

print(italy_variety_year_per_region['count'].describe())

# %%
boxplot_italy = italy_variety_year_per_region.boxplot(column = 'count', figsize = (5,8))

# %%
italy_variety_year_per_region = italy_variety_year_per_region[italy_variety_year_per_region['count'] >= minimum_count_per_region].reset_index().set_index('region_1')

# %%
# snippet on 1 italian region
italy_variety_year_per_region.loc['Alto Adige']

# %%
def get_italy_classified_regions():
    italy_region = italy_variety_year_per_region.index.tolist() # set this list into a unique list 
    myItalylist = set(italy_region)
    myItalylist = list(myItalylist)

    appended_dfs = []
    for region in myItalylist:
        # print(f'===================={region}==========================')
        try:
            varieties = list(italy_variety_year_per_region.loc[str(region)]['variety'].values)
            summary_stat_italy = show_plot(italy_var,region,varieties) ## append this df to another df. 
            appended_dfs.append(summary_stat_italy)
        except:
            variety = pd.DataFrame(italy_variety_year_per_region.loc[str(region)]).transpose()['variety'].values
            summary_stat_italy2 = show_plot(italy_var,region, variety)
            appended_dfs.append(summary_stat_italy2)

    italy_classified_regions = pd.concat(appended_dfs)

    italy_classified_regions['classification'] = np.where((italy_classified_regions['coefficient_years'] < 0) & (italy_classified_regions['p-value-year'] < 0.05) , 'appreciating', 'depreciating')
    italy_classified_regions['country'] = 'Italy'
    print(italy_classified_regions.shape)

italy_classified_regions = get_italy_classified_regions()

# %% [markdown]
# # Spain Regression on Price, Points and Year based on Grape Variety
#
# #### The data I will use for this is the "data_price_df".

# %%
# checking the distribution of the variety per region
spain_var = data_price_df[data_price_df['country'] == 'Spain']
spain_variety_year_per_region = spain_var.groupby(['region_1','variety'])['years'].agg(['count'])

# %%
#check the distribution of the variety in each region 

spain_variety_year_per_region['count'].describe()

# %%
boxplot_spain = spain_variety_year_per_region.boxplot(column = 'count', figsize = (5,8))

# %%
spain_variety_year_per_region = spain_variety_year_per_region[spain_variety_year_per_region['count'] >= minimum_count_per_region].reset_index().set_index('region_1')

# %%
spain_variety_year_per_region.loc['Alicante']

# %%
def get_spain_classified_regions():
    spain_region = spain_variety_year_per_region.index.tolist() # set this list into a unique list 
    mySpainlist = set(spain_region) # get the unique list
    mySpainlist_final = list(mySpainlist)
    print(len(mySpainlist_final))

    appended_dfs = []
    for region in mySpainlist_final:
        # print(f'===================={region}==========================')
        try:
            varieties = list(spain_variety_year_per_region.loc[str(region)]['variety'].values)
            summary_stat_spain = show_plot(spain_var,region,varieties) ## append this df to another df. 
            appended_dfs.append(summary_stat_spain)
        except:
            variety = pd.DataFrame(spain_variety_year_per_region.loc[str(region)]).transpose()['variety'].values
            summary_stat_spain2 = show_plot(spain_var,region, variety)
            appended_dfs.append(summary_stat_spain2)



    spain_classified_regions = pd.concat(appended_dfs)
    
    return spain_classified_regions
        
spain_classified_regions = get_spain_classified_regions()

# %%
spain_classified_regions['classification'] = np.where((spain_classified_regions['coefficient_years'] < 0) & (spain_classified_regions['p-value-year'] < 0.05) , 'appreciating', 'depreciating')
spain_classified_regions['country'] = 'Spain'
spain_classified_regions.shape

# %%
country_list = [france_classified_regions, italy_classified_regions, spain_classified_regions]
all_countries_classification = pd.concat(country_list)
all_countries_classification.shape

# %%
all_countries_classification.head()

# %%
all_countries_classification[all_countries_classification['classification'] == 'appreciating'].shape

# %%
all_countries_classification.to_excel('all_countries_classification- filter 10 region count.xlsx')

# %% [markdown]
# # Correlations between points and scores

# %% [markdown]
# ## France correlation of price and scores
#
# The dataset that we will use is the data_price_df.

# %%
data_price_df[['points','price']].describe()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.hist(data_price_df['price'])
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Wine Prices')
plt.subplot(1, 2, 2)
plt.hist(data_price_df['points'])
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.title('Distribution of Wine Review Points')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,14))
ax = sns.jointplot(x='price', y='points', data=data_price_df[data_price_df['price'] < 200], kind='reg')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,14))
ax = sns.jointplot(x='years', y='points', data=data_price_df[data_price_df['years'] < 1980], kind='reg')
plt.tight_layout()
plt.show()

# %% [markdown]
# Remarks: There is a positive correlation between price and points.

# %%
france = final_data[final_data['country'] == 'France']

# %%
len(france['region_1'].unique()) # france

# %%
spain = final_data[final_data['country'] == 'Spain']
len(spain['region_1'].unique())

# %%
final_data.shape

# %%
final_data.to_excel('wine_final_data.xlsx')

# %%
import pandas as pd
import numpy as np
import os
import re

# %% [markdown]
# # France

# %%
rootdir = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\france"
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        filepath = os.path.join(subdir, file)
        with open(filepath) as f:
            lines = f.readlines()
        next_file_path = re.sub('france','france_cleaned',filepath)
        print(next_file_path)
        with open(next_file_path, "w") as outfile:
            outfile.write("".join(lines[11:]))

# %% [markdown]
# # Italy

# %%
rootdir = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy"
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        filepath = os.path.join(subdir, file)
        with open(filepath) as f:
            lines = f.readlines()
        next_file_path = re.sub('italy','italy_cleaned',filepath)
        print(next_file_path)
        with open(next_file_path, "w") as outfile:
            outfile.write("".join(lines[11:]))
# Out:
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Abruzzo.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Albana di Romagna.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Alcamo.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Alghero.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Alta Langa.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Alto Adige.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\italy_cleaned\Assisi.csv
# ...

# %% [markdown]
# # Spain

# %%
rootdir = r"C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain"
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        filepath = os.path.join(subdir, file)
        with open(filepath) as f:
            lines = f.readlines()
        next_file_path = re.sub('spain','spain_cleaned',filepath)
        print(next_file_path)
        with open(next_file_path, "w") as outfile:
            outfile.write("".join(lines[11:]))
# Out:
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Alella.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Alicante.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Almansa.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Arribes del Duero.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Bierzo.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Bizkaiko Txakolina.csv
# C:\Users\rezan\Documents\Master in Applied Data Science\2nd Year\MASTER THESIS\GIT THESIS\geopy\spain_cleaned\Bullas.csv
# ...
